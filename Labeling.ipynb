# %% [markdown]
# # Label the images

# %% [markdown]
# ## 1. Import the libraries

# %%
pip install labelme tensorflow albumentations
# Out:
# ...
#   Using cached tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
# ...
#      -------------------------------------- 369.4/369.4 kB 3.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.4/1.4 MB 21.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.5/5.5 MB 20.7 MB/s eta 0:00:00
# ...
#      --------------------------------------- 26.4/26.4 MB 15.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.9/2.9 MB 14.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 135.8/135.8 kB 8.4 MB/s eta 0:00:00
# ...
#      --------------------------------------- 12.9/12.9 MB 15.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# ...
#      ------------------------------------- 209.7/209.7 kB 12.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 8.6 MB/s eta 0:00:00
# ...

# %%
import os
import uuid
import cv2

# %% [markdown]
# ## 2. Load the seed dataset

# %%
POSITIVE_IMAGES_PATH = os.path.join('seed', 'braces')
NEGATIVE_IMAGES_PATH = os.path.join('seed', 'no_braces')
positive_images = os.listdir(POSITIVE_IMAGES_PATH)
negative_images = os.listdir(NEGATIVE_IMAGES_PATH)

# %%
positive_images
# Out:
# ['video_10_snapshot_0000.jpg',
#  'video_10_snapshot_0002.jpg',
#  'video_10_snapshot_0003.jpg',
#  'video_10_snapshot_0004.jpg',
#  'video_10_snapshot_0005.jpg',
#  'video_10_snapshot_0008.jpg',
#  'video_10_snapshot_0009.jpg',
#  'video_10_snapshot_0010.jpg',
#  'video_10_snapshot_0011.jpg',
#  'video_10_snapshot_0012.jpg',
#  'video_10_snapshot_0013.jpg',
#  'video_10_snapshot_0014.jpg',
#  'video_10_snapshot_0015.jpg',
#  'video_10_snapshot_0016.jpg',
#  'video_10_snapshot_0018.jpg',
#  'video_10_snapshot_0019.jpg',
#  'video_10_snapshot_0022.jpg',
#  'video_10_snapshot_0023.jpg',
#  'video_10_snapshot_0024.jpg',
#  'video_10_snapshot_0027.jpg',
#  'video_10_snapshot_0028.jpg',
#  'video_10_snapshot_0029.jpg',
#  'video_10_snapshot_0030.jpg',
#  'video_10_snapshot_0031.jpg',
#  'video_10_snapshot_0033.jpg',
#  'video_10_snapshot_0034.jpg',
#  'video_10_snapshot_0035.jpg',
#  'video_10_snapshot_0036.jpg',
#  'video_10_snapshot_0037.jpg',
#  'video_10_snapshot_0038.jpg',
# ...

# %%
negative_images
# Out:
# ['video_10_snapshot_0001.jpg',
#  'video_10_snapshot_0006.jpg',
#  'video_10_snapshot_0007.jpg',
#  'video_10_snapshot_0017.jpg',
#  'video_10_snapshot_0020.jpg',
#  'video_10_snapshot_0021.jpg',
#  'video_10_snapshot_0025.jpg',
#  'video_10_snapshot_0026.jpg',
#  'video_10_snapshot_0032.jpg',
#  'video_10_snapshot_0044.jpg',
#  'video_10_snapshot_0049.jpg',
#  'video_10_snapshot_0055.jpg',
#  'video_10_snapshot_0056.jpg',
#  'video_10_snapshot_0057.jpg',
#  'video_10_snapshot_0061.jpg',
#  'video_10_snapshot_0064.jpg',
#  'video_10_snapshot_0066.jpg',
#  'video_10_snapshot_0067.jpg',
#  'video_10_snapshot_0068.jpg',
#  'video_10_snapshot_0069.jpg',
#  'video_10_snapshot_0070.jpg',
#  'video_10_snapshot_0071.jpg',
#  'video_10_snapshot_0072.jpg',
#  'video_10_snapshot_0073.jpg',
#  'video_10_snapshot_0074.jpg',
#  'video_10_snapshot_0075.jpg',
#  'video_10_snapshot_0076.jpg',
#  'video_10_snapshot_0077.jpg',
#  'video_10_snapshot_0078.jpg',
#  'video_10_snapshot_0079.jpg',
# ...

# %% [markdown]
# Check the number of images

# %%
len(positive_images)
# Out:
# 611

# %%
len(negative_images)
# Out:
# 385

# %%
IMAGES_PATH = positive_images

# %% [markdown]
# # 3. Innotate the images with LabelMe

# %%
# !labelme
# Out:
# Traceback (most recent call last):
#   File "C:\Users\tomzh\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\tomzh\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\tomzh\AppData\Local\Programs\Python\Python310\Scripts\labelme.exe\__main__.py", line 4, in <module>
#     from labelme.__main__ import main
#   File "C:\Users\tomzh\AppData\Local\Programs\Python\Python310\lib\site-packages\labelme\__main__.py", line 17, in <module>
#     from labelme.app import MainWindow
#   File "C:\Users\tomzh\AppData\Local\Programs\Python\Python310\lib\site-packages\labelme\app.py", line 21, in <module>
#     from labelme._automation import bbox_from_text
#   File "C:\Users\tomzh\AppData\Local\Programs\Python\Python310\lib\site-packages\labelme\_automation\bbox_from_text.py", line 6, in <module>
#     import osam
# ...
